# %% [markdown]
# ## Find bucket details

# %%
# !pip install uv
# !uv pip install groundx pydantic python-dotenv

# %%
from groundx import Document, AsyncGroundX, GroundX
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
client = GroundX(api_key=os.getenv("GROUNDX_API_KEY"))

# %%
buckets = client.buckets.list(n=50)
buckets.dict()
# Out:
# {'buckets': [{'bucketId': 23634,
#    'created': datetime.datetime(2025, 12, 11, 11, 1, 56, tzinfo=TzInfo(0)),
#    'fileCount': 1,
#    'fileSize': '162 KB',
#    'name': 'NA_Alex Tipantaxi',
#    'updated': datetime.datetime(2025, 12, 18, 12, 13, 1, tzinfo=TzInfo(0)),
#    'fileTokens': 55408},
#   {'bucketId': 23305,
#    'created': datetime.datetime(2025, 11, 26, 11, 45, 19, tzinfo=TzInfo(0)),
#    'name': 'no-name_no-name',
#    'updated': datetime.datetime(2026, 2, 18, 11, 39, 16, tzinfo=TzInfo(0))},
#   {'bucketId': 23042,
#    'created': datetime.datetime(2025, 11, 14, 20, 2, 17, tzinfo=TzInfo(0)),
#    'fileCount': 57,
#    'fileSize': '67 MB',
#    'name': 'G3328715_William Pino',
#    'updated': datetime.datetime(2026, 1, 8, 7, 31, 32, tzinfo=TzInfo(0)),
#    'fileTokens': 23416173},
#   {'bucketId': 23041,
#    'created': datetime.datetime(2025, 11, 14, 19, 56, 31, tzinfo=TzInfo(0)),
#    'fileCount': 73,
#    'fileSize': '105.9 MB',
#    'name': 'G2758261_Jose Briones',
# ...

# %%
doc_list = client.documents.lookup(id=22997, n= 200)
doc_list.dict()
# Out:
# {'count': 155,
#  'documents': [{'bucketId': 22997,
#    'documentId': 'fd0fdb25-0c71-4d2e-b9ec-a89dc5cc1891',
#    'fileName': 'WC-Erick Barrezueta.pdf',
#    'fileSize': '52 KB',
#    'fileType': 'pdf',
#    'processId': '57da4822-03c3-4eb3-ad2e-b2f290a3548d',
#    'processLevel': 'full',
# ...

# %%
# doc_list = client.documents.lookup(id=13873)
# doc_list.dict()
